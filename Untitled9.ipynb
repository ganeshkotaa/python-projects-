# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attribute1 = ['sunny', 'rainy', '?']
attribute2 = ['high', 'normal', '?']
attribute3 = ['me','you','?']

hypothesis = [['ø', 'ø', 'ø' ]]
for i in attribute1:
    for j in attribute2:
        hypothesis = hypothesis + [[i, j]]
print(f"the Hypothesis set: \n{hypothesis}")

# Read data from a CSV file
data = pd.read_csv('your_data.csv')
print(f"\nData is :\n{data}")

temp_yes = []
temp_no = []
for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))  # Exclude the last element and convert to list
    else:
        temp_no.append(list(i[:-1]))   # Exclude the last element and convert to list

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        if trainingEx[0] != hypothesis[l][0] and hypothesis[l][0] != '?':
            hypothesis.pop(l)
        elif trainingEx[1] != hypothesis[l][1] and hypothesis[l][1] != '?':
            hypothesis.pop(l)
        else:
            l = l + 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        if trainingEx[0] == hypothesis[l][0] and trainingEx[1] == hypothesis[l][1]:
            hypothesis.pop(l)
        elif trainingEx[0] == hypothesis[l][0] and hypothesis[l][1] == '?':
            hypothesis.pop(l)
        elif hypothesis[l][0] == '?' and trainingEx[1] == hypothesis[l][1]:
            hypothesis.pop(l)
        else:
            l = l + 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{ø,ø}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# the Hypothesis set:
# [['ø', 'ø', 'ø'], ['sunny', 'high'], ['sunny', 'normal'], ['sunny', '?'], ['rainy', 'high'], ['rainy', 'normal'], ['rainy', '?'], ['?', 'high'], ['?', 'normal'], ['?', '?']]
#
# Data is :
#      sky humidity papa enjoysport
# 0  sunny     high   me        yes
# 1  sunny     high  you         no
# 2  rainy     high  you         no
# 3  sunny     high   me         no
#
# The version space:
# [['ø', 'ø', 'ø'], ['sunny', 'normal'], ['rainy', 'normal'], ['?', 'normal'], ['?', '?']]

# %%
# Out:
# the Hypothesis set:
# [['ø', 'ø'], ['sunny', 'high'], ['sunny', 'normal'], ['sunny', '?'], ['rainy', 'high'], ['rainy', 'normal'], ['rainy', '?'], ['?', 'high'], ['?', 'normal'], ['?', '?']]
#
# The version space:
# [['sunny', 'high'], ['sunny', '?'], ['?', '?']]

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me','you','?']]

hypothesis = [['ø'] * len(attributes) for _ in range(len(attributes[0]))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis = [h + [j] for h in hypothesis]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if trainingEx[attr_index] == hypothesis[l][attr_index] or hypothesis[l][attr_index] == '?':
                hypothesis.pop(l)
            else:
                l += 1


    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?']]
#
# Data is:
#      sky  humidity papa enjoysport
# 0  sunny      high   me        yes
# 1  sunny      high  you        yes
# 2  rainy      high  you         no
# 3  sunny      high   me        yes
#
# The version space:
# []
#
# The version space:
# []
#
# The version space:
# []

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me','you','?']]

hypothesis = [['ø'] * len(attributes) for _ in range(len(attributes[0]))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis = hypothesis+[[j] for h in hypothesis]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if trainingEx[attr_index] != hypothesis[l][attr_index] and hypothesis[l][attr_index] != '?':
                hypothesis.pop(l)
                break
        else:
            l += 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{ø,ø}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# ...

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me','you','?']]

hypothesis = [['ø'] * len(attributes) for _ in range(len(attributes[0]))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis = [h + [j] for h in hypothesis]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if trainingEx[attr_index] != hypothesis[l][attr_index] and hypothesis[l][attr_index] != '?':
                hypothesis.pop(l)
                break
        else:
            l += 1
    # Increment the loop index correctly outside the inner loop
    l += 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?']]
#
# Data is:
#      sky  humidity papa enjoysport
# 0  sunny      high   me        yes
# 1  sunny      high  you        yes
# 2  rainy      high  you         no
# 3  sunny      high   me        yes
#
# The version space:
# {}

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

# Initialize hypothesis set
hypothesis = [['ø'] * len(attributes) for _ in range(len(attributes[0]))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis = [h + [j] for h in hypothesis]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if trainingEx[attr_index] != hypothesis[l][attr_index] and hypothesis[l][attr_index] != '?':
                hypothesis.pop(l)
                break
        else:
            l += 1
    # Increment the loop index correctly outside the inner loop
    l += 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?']]
#
# Data is:
#      sky humidity papa enjoysport
# 0  sunny     high   me        yes
# 1  sunny     high  you        yes
# 2  rainy     high  you         no
# 3  sunny     high   me        yes
#
# The version space:
# {}

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

# Initialize hypothesis set
hypothesis = [['ø'] * len(attributes[0]) for _ in range(len(attributes))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis[i].append(j)

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes[0])):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes[0])):
            if trainingEx[attr_index] != hypothesis[l][attr_index] and hypothesis[l][attr_index] != '?':
                hypothesis.pop(l)
                break
        else:
            l += 1
    # Increment the loop index correctly outside the inner loop
    l += 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?'], ['ø', 'ø', 'ø', 'high', 'normal', '?'], ['ø', 'ø', 'ø', 'me', 'you', '?']]
#
# Data is:
#      sky humidity papa enjoysport
# 0  sunny     high   me        yes
# 1  sunny     high  you        yes
# 2  rainy     high  you         no
# 3  sunny     high   me        yes
#
# The version space:
# {}

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

# Initialize hypothesis set
hypothesis = [['ø'] * len(attributes[0]) for _ in range(len(attributes[0]))]

for i in range(len(attributes[0])):
    for j in attributes[i]:
        hypothesis[i].append(j)

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes[0])):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes[0])):
            if trainingEx[attr_index] != hypothesis[l][attr_index] and hypothesis[l][attr_index] != '?':
                hypothesis.pop(l)
                break
        else:
            l += 1
    # Increment the loop index correctly outside the inner loop
    l += 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?'], ['ø', 'ø', 'ø', 'high', 'normal', '?'], ['ø', 'ø', 'ø', 'me', 'you', '?']]
#
# Data is:
#      sky humidity papa enjoysport
# 0  sunny     high   me        yes
# 1  sunny     high  you        yes
# 2  rainy     high  you         no
# 3  sunny     high   me        yes
#
# The version space:
# {}

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

hypothesis = [['ø'] * len(attributes) for _ in range(len(attributes[0]))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis = [h + [j] for h in hypothesis]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if trainingEx[attr_index] != hypothesis[l][attr_index] and hypothesis[l][attr_index] != '?':
                hypothesis.pop(l)
                break
        else:
            l += 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?']]
#
# Data is:
#      sky humidity papa enjoysport
# 0  sunny     high   me        yes
# 1  sunny     high  you        yes
# 2  rainy     high  you         no
# 3  sunny     high   me        yes
#
# The version space:
# {}

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

hypothesis = [['ø'] * len(attributes) for _ in range(len(attributes[0]))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis = [h + [j] for h in hypothesis]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if hypothesis[l][attr_index] != '?' and hypothesis[l][attr_index] != trainingEx[attr_index]:
                hypothesis.pop(l)
                break
        else:
            l += 1

concepts = np.array(temp_no)

for trainingEx in concepts:
    l = 0
    while l < len(hypothesis):
        for attr_index in range(len(attributes)):
            if trainingEx[attr_index] != hypothesis[l][attr_index] and hypothesis[l][attr_index] != '?':
                hypothesis.pop(l)
                break
        else:
            l += 1

if len(hypothesis) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{hypothesis}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?'], ['ø', 'ø', 'ø', 'sunny', 'rainy', '?', 'high', 'normal', '?', 'me', 'you', '?']]
#
# Data is:
#      sky humidity papa enjoysport
# 0  sunny     high   me        yes
# 1  sunny     high  you        yes
# 2  rainy     high  you         no
# 3  sunny     high   me        yes
#
# The version space:
# {}

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

hypothesis = [['ø'] * len(attributes[0]) for _ in range(len(attributes))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis[i] = [h + [j] for h in hypothesis[i]]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    for attr_index in range(len(attributes)):
        hypothesis[attr_index] = [h + [trainingEx[attr_index]] for h in hypothesis[attr_index]]

concepts = np.array(temp_no)

for trainingEx in concepts:
    for attr_index in range(len(attributes)):
        hypothesis[attr_index] = [h + ['?'] for h in hypothesis[attr_index] if h[attr_index] == trainingEx[attr_index] or h[attr_index] == '?']

result = []
for i in range(len(attributes)):
    result.extend(hypothesis[i])

if len(result) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{result}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 13
#      11 for i in range(len(attributes)):
#      12     for j in attributes[i]:
# ---> 13         hypothesis[i] = [h + [j] for h in hypothesis[i]]
#      15 print(f"The Hypothesis set:\n{hypothesis}")
#      17 # Assuming your CSV file has column headers as attribute names
#
# Cell In[20], line 13, in <listcomp>(.0)
#      11 for i in range(len(attributes)):
#      12     for j in attributes[i]:
# ---> 13         hypothesis[i] = [h + [j] for h in hypothesis[i]]
#      15 print(f"The Hypothesis set:\n{hypothesis}")
#      17 # Assuming your CSV file has column headers as attribute names
#
# TypeError: can only concatenate str (not "list") to str

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

hypothesis = [['ø'] * len(attributes[0]) for _ in range(len(attributes))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis[i] = [h + [j] for h in hypothesis[i]]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    for attr_index in range(len(attributes)):
        hypothesis[attr_index] = [h + [trainingEx[attr_index]] for h in hypothesis[attr_index]]

concepts = np.array(temp_no)

for trainingEx in concepts:
    for attr_index in range(len(attributes)):
        hypothesis[attr_index] = [h + ['?'] for h in hypothesis[attr_index] if h[attr_index] == trainingEx[attr_index] or h[attr_index] == '?']

result = []
for i in range(len(attributes)):
    result.extend(hypothesis[i])

if len(result) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{result}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 13
#      11 for i in range(len(attributes)):
#      12     for j in attributes[i]:
# ---> 13         hypothesis[i] = [h + [j] for h in hypothesis[i]]
#      15 print(f"The Hypothesis set:\n{hypothesis}")
#      17 # Assuming your CSV file has column headers as attribute names
#
# Cell In[21], line 13, in <listcomp>(.0)
#      11 for i in range(len(attributes)):
#      12     for j in attributes[i]:
# ---> 13         hypothesis[i] = [h + [j] for h in hypothesis[i]]
#      15 print(f"The Hypothesis set:\n{hypothesis}")
#      17 # Assuming your CSV file has column headers as attribute names
#
# TypeError: can only concatenate str (not "list") to str

# %%
import numpy as np
import pandas as pd

# ListThenEliminate
attributes = [['sunny', 'rainy', '?'],
              ['high', 'normal', '?'],
              ['me', 'you', '?']]

hypothesis = [['ø'] * len(attributes[0]) for _ in range(len(attributes))]

for i in range(len(attributes)):
    for j in attributes[i]:
        hypothesis[i] = hypothesis[i] + [j]

print(f"The Hypothesis set:\n{hypothesis}")

# Assuming your CSV file has column headers as attribute names
data = pd.read_csv('your_data.csv')
print(f"\nData is:\n{data}")

temp_yes = []
temp_no = []

for i in data.values:
    if i[-1] == 'yes':
        temp_yes.append(list(i[:-1]))
    else:
        temp_no.append(list(i[:-1]))

concepts = np.array(temp_yes)

for trainingEx in concepts:
    for attr_index in range(len(attributes)):
        hypothesis[attr_index] = [h + [trainingEx[attr_index]] for h in hypothesis[attr_index]]

concepts = np.array(temp_no)

for trainingEx in concepts:
    for attr_index in range(len(attributes)):
        hypothesis[attr_index] = [h + ['?'] for h in hypothesis[attr_index] if h[attr_index] == trainingEx[attr_index] or h[attr_index] == '?']

result = []
for i in range(len(attributes)):
    result.extend(hypothesis[i])

if len(result) == 0:
    print("\nThe version space:\n{}")
else:
    print(f"\nThe version space:\n{result}")
# Out:
# The Hypothesis set:
# [['ø', 'ø', 'ø', 'sunny', 'rainy', '?'], ['ø', 'ø', 'ø', 'high', 'normal', '?'], ['ø', 'ø', 'ø', 'me', 'you', '?']]
#
# Data is:
#      sky humidity papa enjoysport
# 0  sunny     high   me        yes
# 1  sunny     high  you        yes
# 2  rainy     high  you         no
# 3  sunny     high   me        yes
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 34
#      32 for trainingEx in concepts:
#      33     for attr_index in range(len(attributes)):
# ---> 34         hypothesis[attr_index] = [h + [trainingEx[attr_index]] for h in hypothesis[attr_index]]
#      36 concepts = np.array(temp_no)
#      38 for trainingEx in concepts:
#
# Cell In[22], line 34, in <listcomp>(.0)
#      32 for trainingEx in concepts:
#      33     for attr_index in range(len(attributes)):
# ...

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
# Get user input for the data
num_samples = int(input("Enter the number of samples: "))
num_features = int(input("Enter the number of features: "))
# Initialize empty arrays for features and labels
X = np.zeros((num_samples, num_features))
y = np.zeros(num_samples, dtype=int)
# Get user input for each sample
for i in range(num_samples):
 print(f"\nEnter data for sample {i + 1}:")
 for j  j] = float(input(f"Enter feature {j + 1}: "))
 y[i] = int(input("Enter label (0 or 1): "))
# Initialize the KNN classifier
knn = KNeighborsClassifier(n_neighbors=3)
# Train the classifier
knn.fit(X, y)
# Get user input for a new sample
new_sample = np.zeros(num_features)
print("\nEnter data for the new sample:")
for j in range(num_features):
 new_sample[j] = float(input(f"Enter feature {j + 1}: "))
# Make a prediction for the new sample
predicted_label = knn.predict([new_sample])[0]
print(f"\nThe predicted label for the new sample is: {predicted_label}")

# %%
pip install pyC45
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pyC45 (from versions: none)
# ERROR: No matching distribution found for pyC45

# %%
from c45 import C45

# Assuming 'go.csv' has the same structure as before
df = pandas.read_csv("go.csv")

# Map categorical values to numerical values
d_nationality = {'UK': 0, 'USA': 1, 'N': 2}
d_go = {'YES': 1, 'NO': 0}
df['Nationality'] = df['Nationality'].map(d_nationality)
df['Go'] = df['Go'].map(d_go)

# Define features and target variable
features = ['Age', 'Experience', 'Rank', 'Nationality']
X = df[features]
Y = df['Go']

# Initialize C4.5 classifier
c45 = C45()

# Train the classifier
c45.fit(X, Y)

# Visualize the tree
c45.print_tree()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from c45 import C45
#       3 # Assuming 'go.csv' has the same structure as before
#       4 df = pandas.read_csv("go.csv")
#
# ModuleNotFoundError: No module named 'c45'

# %%
pip install pyC45
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pyC45 (from versions: none)
# ERROR: No matching distribution found for pyC45

# %%
from c45 import C45

# Assuming 'go.csv' has the same structure as before
df = pandas.read_csv("go.csv")

# Map categorical values to numerical values
d_nationality = {'UK': 0, 'USA': 1, 'N': 2}
d_go = {'YES': 1, 'NO': 0}
df['Nationality'] = df['Nationality'].map(d_nationality)
df['Go'] = df['Go'].map(d_go)

# Define features and target variable
features = ['Age', 'Experience', 'Rank', 'Nationality']
X = df[features]
Y = df['Go']

# Initialize C4.5 classifier
c45 = C45()

# Train the classifier
c45.fit(X, Y)

# Visualize the tree
c45.print_tree()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from c45 import C45
#       3 # Assuming 'go.csv' has the same structure as before
#       4 df = pandas.read_csv("go.csv")
#
# ModuleNotFoundError: No module named 'c45'
